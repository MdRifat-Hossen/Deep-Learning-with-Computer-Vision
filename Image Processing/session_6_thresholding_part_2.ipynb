# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
# loading image
im_path = '/content/drive/MyDrive/Colab Notebooks/image_processing_batch-2/images/berry-1.jpg'
img = cv.imread(im_path, cv.IMREAD_GRAYSCALE)

# %%
plt.imshow(img)

# %%
img_bgr = cv.imread(im_path)
img_gray = cv.cvtColor(img_bgr, cv.COLOR_BGR2GRAY)
plt.imshow(img_gray)

# %%
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_rgb = cv.cvtColor(img, cv.COLOR_GRAY2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ## Adaptive Thresholding

# %%
img.shape
# Out:
# (331, 235)

# %%
adaptive_mean = cv.adaptiveThreshold(img, 255, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, 5, 2)
plt.imshow(adaptive_mean, 'gray')

# %%
adaptive_gaussian = cv.adaptiveThreshold(img, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, 11, 2)
plt.imshow(adaptive_gaussian, 'gray')

# %% [markdown]
# ## Otsu's Thresholding

# %%
ret1, otsu1 = cv.threshold(img, 160, 255, cv.THRESH_BINARY + cv.THRESH_OTSU)
ret2, otsu2 = cv.threshold(img, 60, 255, cv.THRESH_BINARY + cv.THRESH_OTSU)

plt.subplot(1, 2, 1)
plt.imshow(otsu1, cmap='gray')
# plt.title('Otsu Thresholding (v=160)')

plt.subplot(1, 2, 2)
plt.imshow(otsu2, cmap='gray')
# plt.title('Otsu Thresholding (v=60)')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the table
methods = ["[2] SVM", "[2] NN", "[3] KNN", "[4] SVM", "[4] KNN", "[5] KNN", "[6] SVM", 
           "Ours SVM", "Ours KNN", "Ours RF", "Ours DT"]
accuracies = [80, 89, 77.29, 65.5, 70.87, 77.27, 93.29, 100, 92, 98, 76]

# Bar chart
plt.figure(figsize=(12, 6))
plt.bar(methods, accuracies, color=['blue', 'blue', 'green', 'red', 'red', 'green', 'purple', 
                                    'orange', 'orange', 'orange', 'orange'])

# Labels and title
plt.xlabel("Methods")
plt.ylabel("Accuracy (%)")
plt.title("Comparison of Recognition Rate with State-of-the-Art Methods")
plt.xticks(rotation=5, ha="right")
plt.ylim(60, 105)

# Display the chart
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
