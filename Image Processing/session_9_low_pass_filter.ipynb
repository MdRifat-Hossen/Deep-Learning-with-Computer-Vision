# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/image_processing_batch-2/images/berry-1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')

# %%
median_blur = cv2.medianBlur(img, 5)
plt.imshow(median_blur, cmap='gray')

# %%
gaussian_blur = cv2.GaussianBlur(img, (5,5), 0)
plt.imshow(gaussian_blur, cmap='gray')

# %%
bilateral_blur = cv2.bilateralFilter(img, 5, 75, 75)
plt.imshow(bilateral_blur, cmap='gray')

# %%
# other blur

img = cv2.imread('/content/drive/MyDrive/image_processing_innovative_skills/images/berry-1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
assert img is not None, "file could not be read, check with os.path.exists()"

avg_blur = cv2.blur(img, (5,5))
gaussian_blur = blur = cv.GaussianBlur(img,(5,5),0) # std=0 mean openCV will automatically
median_blur = cv.medianBlur(img, 5)
bilateral_blur = cv.bilateralFilter(img, 5, 75, 75)


plt.figure(figsize=(15, 5))

plt.subplot(141)
plt.imshow(avg_blur, cmap='gray')
plt.title('Averaging')
plt.axis('off')

plt.subplot(142)
plt.imshow(gaussian_blur, cmap='gray')
plt.title('Gaussian')
plt.axis('off')

plt.subplot(143)
plt.imshow(median_blur, cmap='gray')
plt.title('Median')
plt.axis('off')

plt.subplot(144)
plt.imshow(bilateral_blur, cmap='gray')
plt.title('Bilateral')
plt.axis('off')

plt.show()
